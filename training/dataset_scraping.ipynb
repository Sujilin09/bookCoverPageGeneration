# %%
# --- STEP 1: Install dependencies ---
# !pip install pillow imagehash requests tqdm
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.3.0)
# Collecting imagehash
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.11/dist-packages (from imagehash) (1.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imagehash) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from imagehash) (1.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.8.3)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: imagehash
# Successfully installed imagehash-4.3.2

# %%
import os
import csv
import time
import requests
import imagehash
from tqdm import tqdm
from PIL import Image

# %%
# --- STEP 2: Config ---
SEARCH_TERMS = ["fantasy", "romance", "thriller", "science fiction", "mystery"]
MAX_RESULTS_PER_TERM = 50  # adjust to control dataset size
IMAGE_SIZE = (512, 768)  # portrait book cover format
OUTDIR = "book_covers"
META_FILE = "metadata.csv"

os.makedirs(OUTDIR, exist_ok=True)

# %%
# --- STEP 3: Helper - Resize image ---
def resize_cover(infile, outfile, size=IMAGE_SIZE):
    try:
        img = Image.open(infile).convert("RGB")
        img = img.resize(size, Image.LANCZOS)
        img.save(outfile, quality=95)
    except Exception as e:
        print(f"Resize failed for {infile}: {e}")

# %%
# --- STEP 4: Fetch from Open Library ---
def fetch_openlibrary(query, limit=MAX_RESULTS_PER_TERM):
    search_url = 'https://openlibrary.org/search.json'
    params = {'q': query, 'limit': limit}
    try:
        r = requests.get(search_url, params=params).json()
    except Exception as e:
        print(f"Failed to fetch {query}: {e}")
        return []

    rows = []
    for doc in r.get('docs', []):
        cover_id = doc.get('cover_i')
        if not cover_id:
            continue
        cover_url = f'https://covers.openlibrary.org/b/id/{cover_id}-L.jpg'
        fname = os.path.join(OUTDIR, f"{doc.get('key','').replace('/','_')}_{cover_id}.jpg")

        try:
            img_resp = requests.get(cover_url, timeout=10)
            if img_resp.status_code == 200:
                with open(fname, 'wb') as f:
                    f.write(img_resp.content)
                resize_cover(fname, fname)  # resize immediately
                rows.append([
                    doc.get('key'),
                    doc.get('title'),
                    doc.get('author_name', [''])[0],
                    doc.get('first_publish_year'),
                    query,
                    cover_url,
                    fname,
                    'public-domain/unknown',
                    'openlibrary'
                ])
        except Exception as e:
            print("Skip image due to error:", e)

        time.sleep(0.2)  # be nice to API

    return rows

# %%
# --- STEP 5: Collect dataset ---
all_rows = []
for term in SEARCH_TERMS:
    print(f"Fetching covers for genre: {term}")
    rows = fetch_openlibrary(term)
    all_rows.extend(rows)
# Out:
# Fetching covers for genre: fantasy
# Fetching covers for genre: romance
# Fetching covers for genre: thriller
# Fetching covers for genre: science fiction
# Fetching covers for genre: mystery

# %%
# --- STEP 6: Remove duplicates by perceptual hash ---
hashes = {}
unique_rows = []
for row in all_rows:
    img_path = row[6]
    try:
        h = imagehash.phash(Image.open(img_path))
        if str(h) not in hashes:
            hashes[str(h)] = img_path
            unique_rows.append(row)
        else:
            os.remove(img_path)
    except Exception as e:
        print(f"Hash failed for {img_path}: {e}")
# Out:
# Hash failed for book_covers/_works_OL52267W_9009316.jpg: [Errno 2] No such file or directory: 'book_covers/_works_OL52267W_9009316.jpg'
# Hash failed for book_covers/_works_OL52266W_6419199.jpg: [Errno 2] No such file or directory: 'book_covers/_works_OL52266W_6419199.jpg'
# Hash failed for book_covers/_works_OL52114W_36314.jpg: [Errno 2] No such file or directory: 'book_covers/_works_OL52114W_36314.jpg'
# Hash failed for book_covers/_works_OL8193416W_14314858.jpg: [Errno 2] No such file or directory: 'book_covers/_works_OL8193416W_14314858.jpg'
# Hash failed for book_covers/_works_OL472715W_13699667.jpg: [Errno 2] No such file or directory: 'book_covers/_works_OL472715W_13699667.jpg'

# %%
# --- STEP 7: Save metadata ---
with open(META_FILE, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['id','title','author','year','genre','cover_url','cover_filename','license','source'])
    writer.writerows(unique_rows)

print(f"\n✅ Done! Downloaded {len(unique_rows)} unique covers.")
print(f"Images in: {OUTDIR}")
print(f"Metadata saved to: {META_FILE}")
# Out:
# ✅ Done! Downloaded 212 unique covers.
# Images in: book_covers
# Metadata saved to: metadata.csv

# %%
from google.colab import files
files.download("metadata.csv")

# %%
# !zip -r book_covers_dataset.zip book_covers metadata.csv
from google.colab import files
files.download("book_covers_dataset.zip")
# Out:
#   adding: book_covers/ (stored 0%)
#   adding: book_covers/_works_OL98491W_11196262.jpg (deflated 0%)
#   adding: book_covers/_works_OL25595002W_7267770.jpg (deflated 35%)
#   adding: book_covers/_works_OL472572W_12855104.jpg (deflated 0%)
#   adding: book_covers/_works_OL471576W_11100465.jpg (deflated 0%)
#   adding: book_covers/_works_OL81180W_12983362.jpg (deflated 0%)
#   adding: book_covers/_works_OL66562W_9278292.jpg (deflated 0%)
#   adding: book_covers/_works_OL471702W_14586349.jpg (deflated 0%)
#   adding: book_covers/_works_OL77775W_14640067.jpg (deflated 0%)
#   adding: book_covers/_works_OL1168007W_11261770.jpg (deflated 0%)
#   adding: book_covers/_works_OL39360W_3240273.jpg (deflated 1%)
#   adding: book_covers/_works_OL472536W_14577913.jpg (deflated 0%)
#   adding: book_covers/_works_OL80609W_6581958.jpg (deflated 0%)
#   adding: book_covers/_works_OL24034W_13859660.jpg (deflated 1%)
#   adding: book_covers/_works_OL54158W_9173884.jpg (deflated 0%)
#   adding: book_covers/_works_OL262438W_9247987.jpg (deflated 0%)
#   adding: book_covers/_works_OL262454W_8063264.jpg (deflated 1%)
#   adding: book_covers/_works_OL472165W_12996556.jpg (deflated 0%)
#   adding: book_covers/_works_OL71124W_6529226.jpg (deflated 0%)
#   adding: book_covers/_works_OL1833989W_8245407.jpg (deflated 0%)
#   adding: book_covers/_works_OL27455W_14627062.jpg (deflated 0%)
#   adding: book_covers/_works_OL99499W_28174.jpg (deflated 0%)
#   adding: book_covers/_works_OL76835W_14553479.jpg (deflated 0%)
#   adding: book_covers/_works_OL103128W_9345484.jpg (deflated 0%)
#   adding: book_covers/_works_OL52260W_8081288.jpg (deflated 0%)
#   adding: book_covers/_works_OL18417W_552443.jpg (deflated 0%)
#   adding: book_covers/_works_OL7966242W_9292332.jpg (deflated 1%)
#   adding: book_covers/_works_OL472549W_11153508.jpg (deflated 0%)
#   adding: book_covers/_works_OL49488W_12996033.jpg (deflated 0%)
#   adding: book_covers/_works_OL472458W_14578132.jpg (deflated 0%)
#   adding: book_covers/_works_OL1095427W_8235363.jpg (deflated 0%)
#   adding: book_covers/_works_OL472594W_10249139.jpg (deflated 0%)
#   adding: book_covers/_works_OL468431W_10590366.jpg (deflated 1%)
#   adding: book_covers/_works_OL17453W_295537.jpg (deflated 0%)
#   adding: book_covers/_works_OL468485W_6984433.jpg (deflated 0%)
#   adding: book_covers/_works_OL262421W_6717853.jpg (deflated 0%)
#   adding: book_covers/_works_OL471670W_12996554.jpg (deflated 0%)
#   adding: book_covers/_works_OL8763776W_13130696.jpg (deflated 0%)
#   adding: book_covers/_works_OL6583284W_13192917.jpg (deflated 0%)
#   adding: book_covers/_works_OL1066524W_9267223.jpg (deflated 0%)
#   adding: book_covers/_works_OL472470W_12387503.jpg (deflated 1%)
#   adding: book_covers/_works_OL39379W_6559057.jpg (deflated 0%)
#   adding: book_covers/_works_OL54031W_9168732.jpg (deflated 0%)
#   adding: book_covers/_works_OL76836W_8396115.jpg (deflated 0%)
#   adding: book_covers/_works_OL471767W_9492111.jpg (deflated 0%)
#   adding: book_covers/_works_OL471637W_6469172.jpg (deflated 1%)
#   adding: book_covers/_works_OL46125W_14612610.jpg (deflated 0%)
#   adding: book_covers/_works_OL262384W_1814237.jpg (deflated 0%)
#   adding: book_covers/_works_OL27482W_14627509.jpg (deflated 0%)
#   adding: book_covers/_works_OL27448W_14625765.jpg (deflated 0%)
#   adding: book_covers/_works_OL471905W_13672855.jpg (deflated 0%)
#   adding: book_covers/_works_OL103123W_12993656.jpg (deflated 0%)
#   adding: book_covers/_works_OL71042W_1072931.jpg (deflated 0%)
#   adding: book_covers/_works_OL36371W_2132494.jpg (deflated 0%)
#   adding: book_covers/_works_OL3388961W_921610.jpg (deflated 11%)
#   adding: book_covers/_works_OL176092W_8237041.jpg (deflated 0%)
#   adding: book_covers/_works_OL14873315W_8373389.jpg (deflated 1%)
#   adding: book_covers/_works_OL2895536W_973851.jpg (deflated 0%)
#   adding: book_covers/_works_OL76837W_9255229.jpg (deflated 0%)
#   adding: book_covers/_works_OL18412W_12648659.jpg (deflated 0%)
#   adding: book_covers/_works_OL471565W_11172296.jpg (deflated 0%)
#   adding: book_covers/_works_OL468488W_8243609.jpg (deflated 0%)
#   adding: book_covers/_works_OL46309W_9261324.jpg (deflated 0%)
#   adding: book_covers/_works_OL472526W_13679064.jpg (deflated 0%)
#   adding: book_covers/_works_OL59688W_14630668.jpg (deflated 0%)
#   adding: book_covers/_works_OL471666W_14578138.jpg (deflated 0%)
#   adding: book_covers/_works_OL262426W_8350410.jpg (deflated 15%)
#   adding: book_covers/_works_OL455663W_8241487.jpg (deflated 0%)
#   adding: book_covers/_works_OL29983W_8775559.jpg (deflated 0%)
#   adding: book_covers/_works_OL18415W_12648657.jpg (deflated 1%)
#   adding: book_covers/_works_OL183675W_6468730.jpg (deflated 0%)
#   adding: book_covers/_works_OL472189W_14578123.jpg (deflated 0%)
#   adding: book_covers/_works_OL71058W_9184792.jpg (deflated 0%)
#   adding: book_covers/_works_OL103134W_9346537.jpg (deflated 1%)
#   adding: book_covers/_works_OL27258W_283860.jpg (deflated 0%)
#   adding: book_covers/_works_OL110971W_10832290.jpg (deflated 1%)
#   adding: book_covers/_works_OL27513W_14627060.jpg (deflated 0%)
#   adding: book_covers/_works_OL76524W_93020.jpg (deflated 2%)
#   adding: book_covers/_works_OL2172454W_5018327.jpg (deflated 0%)
#   adding: book_covers/_works_OL244537W_4849549.jpg (deflated 0%)
#   adding: book_covers/_works_OL20844W_8236915.jpg (deflated 0%)
#   adding: book_covers/_works_OL476846W_6299936.jpg (deflated 2%)
#   adding: book_covers/_works_OL76833W_11408459.jpg (deflated 0%)
#   adding: book_covers/_works_OL471871W_10249524.jpg (deflated 0%)
#   adding: book_covers/_works_OL471832W_11160095.jpg (deflated 0%)
#   adding: book_covers/_works_OL2163649W_12986869.jpg (deflated 0%)
#   adding: book_covers/_works_OL472049W_13671433.jpg (deflated 0%)
#   adding: book_covers/_works_OL71069W_45897.jpg (deflated 0%)
#   adding: book_covers/_works_OL471841W_12855074.jpg (deflated 0%)
#   adding: book_covers/_works_OL450063W_12356249.jpg (deflated 0%)
#   adding: book_covers/_works_OL1099513W_5890987.jpg (deflated 0%)
#   adding: book_covers/_works_OL381550W_968312.jpg (deflated 1%)
#   adding: book_covers/_works_OL471664W_13151831.jpg (deflated 0%)
#   adding: book_covers/_works_OL38494W_6424001.jpg (deflated 2%)
#   adding: book_covers/_works_OL15450151W_8231834.jpg (deflated 0%)
#   adding: book_covers/_works_OL893415W_11481354.jpg (deflated 1%)
#   adding: book_covers/_works_OL362427W_8257991.jpg (deflated 0%)
#   adding: book_covers/_works_OL71132W_9184719.jpg (deflated 0%)
#   adding: book_covers/_works_OL36861W_11929973.jpg (deflated 1%)
#   adding: book_covers/_works_OL24166W_8267822.jpg (deflated 0%)
#   adding: book_covers/_works_OL2564006W_6614001.jpg (deflated 1%)
#   adding: book_covers/_works_OL505781W_5277723.jpg (deflated 0%)
#   adding: book_covers/_works_OL471500W_13151352.jpg (deflated 0%)
#   adding: book_covers/_works_OL99541W_6644514.jpg (deflated 0%)
#   adding: book_covers/_works_OL1003017W_123152.jpg (deflated 0%)
#   adding: book_covers/_works_OL8127201W_4752788.jpg (deflated 71%)
#   adding: book_covers/_works_OL21177W_12818862.jpg (deflated 0%)
#   adding: book_covers/_works_OL66513W_9278312.jpg (deflated 1%)
#   adding: book_covers/_works_OL262477W_9246467.jpg (deflated 0%)
#   adding: book_covers/_works_OL35627W_288149.jpg (deflated 1%)
#   adding: book_covers/_works_OL462007W_8237052.jpg (deflated 0%)
#   adding: book_covers/_works_OL262452W_8243267.jpg (deflated 0%)
#   adding: book_covers/_works_OL863808W_314235.jpg (deflated 1%)
#   adding: book_covers/_works_OL872773W_3221083.jpg (deflated 0%)
#   adding: book_covers/_works_OL81626W_9256043.jpg (deflated 0%)
#   adding: book_covers/_works_OL52151W_574886.jpg (deflated 1%)
#   adding: book_covers/_works_OL276386W_181493.jpg (deflated 1%)
#   adding: book_covers/_works_OL74504W_8236920.jpg (deflated 0%)
#   adding: book_covers/_works_OL471765W_6874620.jpg (deflated 1%)
#   adding: book_covers/_works_OL471940W_13670505.jpg (deflated 1%)
#   adding: book_covers/_works_OL10834W_10910286.jpg (deflated 1%)
#   adding: book_covers/_works_OL46390W_6502517.jpg (deflated 1%)
#   adding: book_covers/_works_OL471891W_14570595.jpg (deflated 0%)
#   adding: book_covers/_works_OL472324W_11433305.jpg (deflated 0%)
#   adding: book_covers/_works_OL471509W_14573514.jpg (deflated 0%)
#   adding: book_covers/_works_OL100239W_12728401.jpg (deflated 0%)
#   adding: book_covers/_works_OL14868510W_9279273.jpg (deflated 0%)
#   adding: book_covers/_works_OL14860424W_1047466.jpg (deflated 0%)
#   adding: book_covers/_works_OL39108W_8239401.jpg (deflated 0%)
#   adding: book_covers/_works_OL731737W_802982.jpg (deflated 6%)
#   adding: book_covers/_works_OL1960472W_6941459.jpg (deflated 0%)
#   adding: book_covers/_works_OL8996439W_8598263.jpg (deflated 1%)
#   adding: book_covers/_works_OL66554W_14348537.jpg (deflated 0%)
#   adding: book_covers/_works_OL38684W_8236295.jpg (deflated 0%)
#   adding: book_covers/_works_OL8483260W_14376136.jpg (deflated 0%)
#   adding: book_covers/_works_OL471610W_12855259.jpg (deflated 0%)
#   adding: book_covers/_works_OL471932W_13151356.jpg (deflated 0%)
#   adding: book_covers/_works_OL273080W_382159.jpg (deflated 1%)
#   adding: book_covers/_works_OL99539W_902122.jpg (deflated 0%)
#   adding: book_covers/_works_OL1099915W_1277096.jpg (deflated 0%)
#   adding: book_covers/_works_OL66614W_12641526.jpg (deflated 12%)
#   adding: book_covers/_works_OL1095397W_11024634.jpg (deflated 0%)
#   adding: book_covers/_works_OL1168083W_9267242.jpg (deflated 0%)
#   adding: book_covers/_works_OL66544W_12824691.jpg (deflated 0%)
#   adding: book_covers/_works_OL27495W_14627042.jpg (deflated 0%)
#   adding: book_covers/_works_OL14877871W_6960817.jpg (deflated 3%)
#   adding: book_covers/_works_OL23797W_2293974.jpg (deflated 0%)
#   adding: book_covers/_works_OL36287W_14566393.jpg (deflated 0%)
#   adding: book_covers/_works_OL138052W_10527843.jpg (deflated 0%)
#   adding: book_covers/_works_OL455327W_8684447.jpg (deflated 2%)
#   adding: book_covers/_works_OL893707W_12993424.jpg (deflated 0%)
#   adding: book_covers/_works_OL962240W_12975462.jpg (deflated 0%)
#   adding: book_covers/_works_OL265415W_6379981.jpg (deflated 0%)
#   adding: book_covers/_works_OL471771W_14578204.jpg (deflated 0%)
#   adding: book_covers/_works_OL66059W_825884.jpg (deflated 0%)
#   adding: book_covers/_works_OL71078W_6950992.jpg (deflated 0%)
#   adding: book_covers/_works_OL59849W_4437200.jpg (deflated 32%)
#   adding: book_covers/_works_OL472250W_10247294.jpg (deflated 1%)
#   adding: book_covers/_works_OL471784W_14575632.jpg (deflated 0%)
#   adding: book_covers/_works_OL267096W_2560652.jpg (deflated 1%)
#   adding: book_covers/_works_OL471776W_11165070.jpg (deflated 0%)
#   adding: book_covers/_works_OL450124W_882662.jpg (deflated 0%)
#   adding: book_covers/_works_OL471667W_14561660.jpg (deflated 0%)
#   adding: book_covers/_works_OL99529W_4342323.jpg (deflated 0%)
#   adding: book_covers/_works_OL27479W_14627564.jpg (deflated 0%)
#   adding: book_covers/_works_OL80947W_6485299.jpg (deflated 3%)
#   adding: book_covers/_works_OL455512W_8245179.jpg (deflated 0%)
#   adding: book_covers/_works_OL15366912W_7222976.jpg (deflated 0%)
#   adding: book_covers/_works_OL66534W_12567961.jpg (deflated 0%)
#   adding: book_covers/_works_OL76350W_6268135.jpg (deflated 0%)
#   adding: book_covers/_works_OL151515W_129771.jpg (deflated 0%)
#   adding: book_covers/_works_OL471895W_12996560.jpg (deflated 0%)
#   adding: book_covers/_works_OL85753W_5540820.jpg (deflated 1%)
#   adding: book_covers/_works_OL77559W_419378.jpg (deflated 1%)
#   adding: book_covers/_works_OL46224W_9300695.jpg (deflated 0%)
#   adding: book_covers/_works_OL471943W_12996535.jpg (deflated 0%)
#   adding: book_covers/_works_OL28993W_12614549.jpg (deflated 0%)
#   adding: book_covers/_works_OL10215W_5484189.jpg (deflated 3%)
#   adding: book_covers/_works_OL471990W_10561150.jpg (deflated 0%)
#   adding: book_covers/_works_OL77744W_14638062.jpg (deflated 0%)
#   adding: book_covers/_works_OL16249171W_320591.jpg (deflated 0%)
#   adding: book_covers/_works_OL5735363W_12646537.jpg (deflated 0%)
#   adding: metadata.csv (deflated 80%)

# %% [markdown]
# **ONE LINE PLOT**

# %%
from transformers import pipeline
import pandas as pd
import requests
import json
from tqdm import tqdm

# %%
# --- Load existing metadata ---
df = pd.read_csv("/content/metadata.csv")

# %%
# --- Summarizer ---
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", device=0)

def fetch_description(olid):
    """Fetch description text from Open Library given a work OLID like '/works/OL12345W'."""
    olid_clean = olid.split("/")[-1]
    url = f"https://openlibrary.org/works/{olid_clean}.json"
    try:
        r = requests.get(url).json()
        desc = r.get("description", "")
        if isinstance(desc, dict):
            desc = desc.get("value", "")
        return desc
    except:
        return ""

def make_one_line(desc):
    """Convert a long description into a 1-line plot."""
    if not desc or len(desc.split()) < 8:
        return ""
    try:
        summary = summarizer(desc, max_length=25, min_length=15, do_sample=False)
        return summary[0]['summary_text']
    except:
        return desc[:120]  # fallback: truncate
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
# --- Process each row ---
one_line_plots = []
for idx, row in tqdm(df.iterrows(), total=len(df)):
    desc = fetch_description(row['id'])
    plot = make_one_line(desc)
    one_line_plots.append(plot)

df['one_line_plot'] = one_line_plots
# Out:
#   5%|▌         | 11/212 [00:05<01:27,  2.30it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#  18%|█▊        | 39/212 [00:18<01:29,  1.94it/s]Your max_length is set to 25, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  61%|██████▏   | 130/212 [01:07<00:40,  2.03it/s]Your max_length is set to 25, but your input_length is only 23. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
#  64%|██████▍   | 136/212 [01:10<00:37,  2.02it/s]Your max_length is set to 25, but your input_length is only 22. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=11)
# 100%|██████████| 212/212 [01:45<00:00,  2.02it/s]

# %%
# --- Save enriched metadata ---
df.to_csv("metadata_with_plots.csv", index=False)
print("\n✅ Metadata updated with one_line_plot column.")
# Out:
# ✅ Metadata updated with one_line_plot column.

# %%
from google.colab import files
files.download("metadata_with_plots.csv")

# %%
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm

# Paths
metadata_path = "metadata_with_plots.csv"
images_path = "book_covers"
output_images_path = "lora_dataset/images"
output_captions_path = "lora_dataset/captions"

# Create output folders
os.makedirs(output_images_path, exist_ok=True)
os.makedirs(output_captions_path, exist_ok=True)

# Load metadata
df = pd.read_csv(metadata_path)

# Preprocess each image
for idx, row in tqdm(df.iterrows(), total=len(df)):
    img_filename = row['cover_filename']
    img_path = os.path.join(images_path, os.path.basename(img_filename))

    if not os.path.exists(img_path):
        continue  # skip missing images

    try:
        # Open and resize image
        img = Image.open(img_path).convert("RGB")
        img = img.resize((512, 512), Image.Resampling.LANCZOS)

        # Save to new dataset folder
        img_out_path = os.path.join(output_images_path, f"{idx:04d}.jpg")
        img.save(img_out_path, "JPEG", quality=95)

        # Create caption file
        prompt = f"Title: {row['title']}. Plot: {row['one_line_plot']}."
        caption_out_path = os.path.join(output_captions_path, f"{idx:04d}.txt")
        with open(caption_out_path, "w", encoding="utf-8") as f:
            f.write(prompt)

    except Exception as e:
        print(f"Error processing {img_path}: {e}")

print("✅ Dataset ready for LoRA training in 'lora_dataset/'")
# Out:
# 100%|██████████| 212/212 [00:01<00:00, 113.55it/s]
# ✅ Dataset ready for LoRA training in 'lora_dataset/'

# %%
# Zip your dataset and offer it for download
# !zip -r book_cover_dataset.zip book_covers metadata_with_plots.csv metadata.csv lora_dataset 2>/dev/null || true

from google.colab import files
files.download("book_cover_dataset.zip")
# Out:
#   adding: book_covers/ (stored 0%)
#   adding: book_covers/_works_OL98491W_11196262.jpg (deflated 0%)
#   adding: book_covers/_works_OL25595002W_7267770.jpg (deflated 35%)
#   adding: book_covers/_works_OL472572W_12855104.jpg (deflated 0%)
#   adding: book_covers/_works_OL471576W_11100465.jpg (deflated 0%)
#   adding: book_covers/_works_OL81180W_12983362.jpg (deflated 0%)
#   adding: book_covers/_works_OL66562W_9278292.jpg (deflated 0%)
#   adding: book_covers/_works_OL471702W_14586349.jpg (deflated 0%)
#   adding: book_covers/_works_OL77775W_14640067.jpg (deflated 0%)
#   adding: book_covers/_works_OL1168007W_11261770.jpg (deflated 0%)
#   adding: book_covers/_works_OL39360W_3240273.jpg (deflated 1%)
#   adding: book_covers/_works_OL472536W_14577913.jpg (deflated 0%)
#   adding: book_covers/_works_OL80609W_6581958.jpg (deflated 0%)
#   adding: book_covers/_works_OL24034W_13859660.jpg (deflated 1%)
#   adding: book_covers/_works_OL2895536W_973851.jpg (deflated 0%)
#   adding: book_covers/_works_OL76837W_9255229.jpg (deflated 0%)
#   adding: book_covers/_works_OL18412W_12648659.jpg (deflated 0%)
#   adding: book_covers/_works_OL471565W_11172296.jpg (deflated 0%)
#   adding: book_covers/_works_OL468488W_8243609.jpg (deflated 0%)
#   adding: book_covers/_works_OL46309W_9261324.jpg (deflated 0%)
#   adding: book_covers/_works_OL472526W_13679064.jpg (deflated 0%)
#   adding: book_covers/_works_OL59688W_14630668.jpg (deflated 0%)
#   adding: book_covers/_works_OL471666W_14578138.jpg (deflated 0%)
#   adding: book_covers/_works_OL262426W_8350410.jpg (deflated 15%)
#   adding: book_covers/_works_OL455663W_8241487.jpg (deflated 0%)
#   adding: book_covers/_works_OL29983W_8775559.jpg (deflated 0%)
#   adding: book_covers/_works_OL18415W_12648657.jpg (deflated 1%)
#   adding: book_covers/_works_OL183675W_6468730.jpg (deflated 0%)
#   adding: book_covers/_works_OL472189W_14578123.jpg (deflated 0%)
#   adding: book_covers/_works_OL71058W_9184792.jpg (deflated 0%)
#   adding: book_covers/_works_OL103134W_9346537.jpg (deflated 1%)
#   adding: book_covers/_works_OL27258W_283860.jpg (deflated 0%)
#   adding: book_covers/_works_OL110971W_10832290.jpg (deflated 1%)
#   adding: book_covers/_works_OL27513W_14627060.jpg (deflated 0%)
#   adding: book_covers/_works_OL76524W_93020.jpg (deflated 2%)
#   adding: book_covers/_works_OL2172454W_5018327.jpg (deflated 0%)
#   adding: book_covers/_works_OL244537W_4849549.jpg (deflated 0%)
#   adding: book_covers/_works_OL20844W_8236915.jpg (deflated 0%)
#   adding: book_covers/_works_OL476846W_6299936.jpg (deflated 2%)
#   adding: book_covers/_works_OL76833W_11408459.jpg (deflated 0%)
#   adding: book_covers/_works_OL471871W_10249524.jpg (deflated 0%)
#   adding: book_covers/_works_OL471832W_11160095.jpg (deflated 0%)
#   adding: book_covers/_works_OL2163649W_12986869.jpg (deflated 0%)
#   adding: book_covers/_works_OL472049W_13671433.jpg (deflated 0%)
#   adding: book_covers/_works_OL71069W_45897.jpg (deflated 0%)
#   adding: book_covers/_works_OL471841W_12855074.jpg (deflated 0%)
#   adding: book_covers/_works_OL450063W_12356249.jpg (deflated 0%)
#   adding: book_covers/_works_OL1099513W_5890987.jpg (deflated 0%)
#   adding: book_covers/_works_OL381550W_968312.jpg (deflated 1%)
#   adding: book_covers/_works_OL471664W_13151831.jpg (deflated 0%)
#   adding: book_covers/_works_OL38494W_6424001.jpg (deflated 2%)
#   adding: book_covers/_works_OL15450151W_8231834.jpg (deflated 0%)
#   adding: book_covers/_works_OL893415W_11481354.jpg (deflated 1%)
#   adding: book_covers/_works_OL362427W_8257991.jpg (deflated 0%)
#   adding: book_covers/_works_OL71132W_9184719.jpg (deflated 0%)
#   adding: book_covers/_works_OL36861W_11929973.jpg (deflated 1%)
#   adding: book_covers/_works_OL24166W_8267822.jpg (deflated 0%)
#   adding: book_covers/_works_OL2564006W_6614001.jpg (deflated 1%)
#   adding: book_covers/_works_OL505781W_5277723.jpg (deflated 0%)
#   adding: book_covers/_works_OL471500W_13151352.jpg (deflated 0%)
#   adding: book_covers/_works_OL99541W_6644514.jpg (deflated 0%)
#   adding: book_covers/_works_OL1003017W_123152.jpg (deflated 0%)
#   adding: book_covers/_works_OL8127201W_4752788.jpg (deflated 71%)
#   adding: book_covers/_works_OL21177W_12818862.jpg (deflated 0%)
#   adding: book_covers/_works_OL66513W_9278312.jpg (deflated 1%)
#   adding: book_covers/_works_OL262477W_9246467.jpg (deflated 0%)
#   adding: book_covers/_works_OL35627W_288149.jpg (deflated 1%)
#   adding: book_covers/_works_OL462007W_8237052.jpg (deflated 0%)
#   adding: book_covers/_works_OL262452W_8243267.jpg (deflated 0%)
#   adding: book_covers/_works_OL863808W_314235.jpg (deflated 1%)
#   adding: book_covers/_works_OL872773W_3221083.jpg (deflated 0%)
#   adding: book_covers/_works_OL81626W_9256043.jpg (deflated 0%)
#   adding: book_covers/_works_OL52151W_574886.jpg (deflated 1%)
#   adding: book_covers/_works_OL276386W_181493.jpg (deflated 1%)
#   adding: book_covers/_works_OL74504W_8236920.jpg (deflated 0%)
#   adding: book_covers/_works_OL471765W_6874620.jpg (deflated 1%)
#   adding: book_covers/_works_OL471940W_13670505.jpg (deflated 1%)
#   adding: book_covers/_works_OL10834W_10910286.jpg (deflated 1%)
#   adding: book_covers/_works_OL46390W_6502517.jpg (deflated 1%)
#   adding: book_covers/_works_OL471891W_14570595.jpg (deflated 0%)
#   adding: book_covers/_works_OL472324W_11433305.jpg (deflated 0%)
#   adding: book_covers/_works_OL471509W_14573514.jpg (deflated 0%)
#   adding: book_covers/_works_OL100239W_12728401.jpg (deflated 0%)
#   adding: book_covers/_works_OL14868510W_9279273.jpg (deflated 0%)
#   adding: book_covers/_works_OL14860424W_1047466.jpg (deflated 0%)
#   adding: book_covers/_works_OL39108W_8239401.jpg (deflated 0%)
#   adding: book_covers/_works_OL731737W_802982.jpg (deflated 6%)
#   adding: book_covers/_works_OL1960472W_6941459.jpg (deflated 0%)
#   adding: book_covers/_works_OL8996439W_8598263.jpg (deflated 1%)
#   adding: book_covers/_works_OL66554W_14348537.jpg (deflated 0%)
#   adding: book_covers/_works_OL38684W_8236295.jpg (deflated 0%)
#   adding: book_covers/_works_OL8483260W_14376136.jpg (deflated 0%)
#   adding: book_covers/_works_OL471610W_12855259.jpg (deflated 0%)
#   adding: book_covers/_works_OL471932W_13151356.jpg (deflated 0%)
#   adding: book_covers/_works_OL273080W_382159.jpg (deflated 1%)
#   adding: book_covers/_works_OL99539W_902122.jpg (deflated 0%)
#   adding: book_covers/_works_OL1099915W_1277096.jpg (deflated 0%)
#   adding: book_covers/_works_OL66614W_12641526.jpg (deflated 12%)
#   adding: book_covers/_works_OL1095397W_11024634.jpg (deflated 0%)
#   adding: book_covers/_works_OL1168083W_9267242.jpg (deflated 0%)
#   adding: book_covers/_works_OL66544W_12824691.jpg (deflated 0%)
#   adding: book_covers/_works_OL27495W_14627042.jpg (deflated 0%)
#   adding: book_covers/_works_OL14877871W_6960817.jpg (deflated 3%)
#   adding: book_covers/_works_OL23797W_2293974.jpg (deflated 0%)
#   adding: book_covers/_works_OL36287W_14566393.jpg (deflated 0%)
#   adding: book_covers/_works_OL138052W_10527843.jpg (deflated 0%)
#   adding: book_covers/_works_OL455327W_8684447.jpg (deflated 2%)
#   adding: book_covers/_works_OL893707W_12993424.jpg (deflated 0%)
#   adding: book_covers/_works_OL962240W_12975462.jpg (deflated 0%)
#   adding: book_covers/_works_OL265415W_6379981.jpg (deflated 0%)
#   adding: book_covers/_works_OL471771W_14578204.jpg (deflated 0%)
#   adding: book_covers/_works_OL66059W_825884.jpg (deflated 0%)
#   adding: book_covers/_works_OL71078W_6950992.jpg (deflated 0%)
#   adding: book_covers/_works_OL59849W_4437200.jpg (deflated 32%)
#   adding: book_covers/_works_OL472250W_10247294.jpg (deflated 1%)
#   adding: book_covers/_works_OL471784W_14575632.jpg (deflated 0%)
#   adding: book_covers/_works_OL267096W_2560652.jpg (deflated 1%)
#   adding: book_covers/_works_OL471776W_11165070.jpg (deflated 0%)
#   adding: book_covers/_works_OL450124W_882662.jpg (deflated 0%)
#   adding: book_covers/_works_OL471667W_14561660.jpg (deflated 0%)
#   adding: book_covers/_works_OL99529W_4342323.jpg (deflated 0%)
#   adding: book_covers/_works_OL27479W_14627564.jpg (deflated 0%)
#   adding: book_covers/_works_OL80947W_6485299.jpg (deflated 3%)
#   adding: book_covers/_works_OL455512W_8245179.jpg (deflated 0%)
#   adding: book_covers/_works_OL15366912W_7222976.jpg (deflated 0%)
#   adding: book_covers/_works_OL66534W_12567961.jpg (deflated 0%)
#   adding: book_covers/_works_OL76350W_6268135.jpg (deflated 0%)
#   adding: book_covers/_works_OL151515W_129771.jpg (deflated 0%)
#   adding: book_covers/_works_OL471895W_12996560.jpg (deflated 0%)
#   adding: book_covers/_works_OL85753W_5540820.jpg (deflated 1%)
#   adding: book_covers/_works_OL77559W_419378.jpg (deflated 1%)
#   adding: book_covers/_works_OL46224W_9300695.jpg (deflated 0%)
#   adding: book_covers/_works_OL471943W_12996535.jpg (deflated 0%)
#   adding: book_covers/_works_OL28993W_12614549.jpg (deflated 0%)
#   adding: book_covers/_works_OL10215W_5484189.jpg (deflated 3%)
#   adding: book_covers/_works_OL471990W_10561150.jpg (deflated 0%)
#   adding: book_covers/_works_OL77744W_14638062.jpg (deflated 0%)
#   adding: book_covers/_works_OL16249171W_320591.jpg (deflated 0%)
#   adding: book_covers/_works_OL5735363W_12646537.jpg (deflated 0%)
#   adding: metadata_with_plots.csv (deflated 71%)
#   adding: metadata.csv (deflated 80%)
#   adding: lora_dataset/ (stored 0%)
#   adding: lora_dataset/images/ (stored 0%)
#   adding: lora_dataset/images/0095.jpg (deflated 1%)
